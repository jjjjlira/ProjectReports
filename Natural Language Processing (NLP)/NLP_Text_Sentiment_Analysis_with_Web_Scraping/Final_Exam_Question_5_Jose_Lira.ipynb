# %% [markdown]
# ### Sentiment Analysis and Web Scraping

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import seaborn as sns
import warnings

from scipy import stats


from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
# from lightgbm import LGBMClassifier
# from sklearn.ensemble import HistGradientBoostingClassifier
# from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
# from numpy.random import RandomState
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score



# Ignore notebook warnings to keep it clearer
# warnings.filterwarnings('ignore')

# This is a magic function that renders the plot in the notebook itself.
# %matplotlib inline 
# To see all the content in the colu

# %%
from bs4 import BeautifulSoup   # Python package for parsing HTML and XML documents used for web scraping.
import requests                 # Requests is a simple HTTP library.
import re                       # Regular Expressions library

# %%
# Setting options to display all rows and columns
pd.options.display.max_columns = None
# pd.options.display.max_rows = None

# %%
URL= " https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"
page = requests.get(URL)

print(page.text)
# Out:
# /,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-CA" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b05852393ae5/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>
#             window.yelp = window.yelp || {};
#             window.yelp.cookieTypePreferencesHeader = '["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]';
#
#             function addCookieManagementScript() {
#                 var tag = document.createElement('script');
#                 tag.async = true;
#                 tag.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';
#                 tag.type = 'text/javascript';
#                 tag.charset = 'UTF-8';
#                 tag.setAttribute('data-domain-script', '740779ac-cc0a-4478-9776-83d073df8f9a');
#                 tag.setAttribute('data-document-language', 'true');
#
#                 document.head.appendChild(tag);
#             }
#
#             if ('requestIdleCallback' in window) {
#                 requestIdleCallback(addCookieManagementScript, { timeout: 4000 });
#             } else {
#                 setTimeout(addCookieManagementScript, 2000);
#             }
#         </script><script async src="https://www.google-analytics.com/analytics.js"></script><meta id="emotion-container"><style data-emotion-css="0 xl0fej quqnuc cfcjyn na3oda xlzvdl ux5mu6 chan6m 1evauet 1jp7iek 1enow5j 79elbk 1xf2c4d 7z2yta 12j7n3g aurft1 z8bp47 1r871ch 18sebrt e5p3ee e0tek0 ije6j5 1fygppl 1udg11w 9vivtc 1sb02f4 ralh0w 1u89q5b wonnhn 1fkqezt 1pz4y59 1m051bw qgunke 1nrzw89 1fnccdf 9hjhab inq9gi 1c2abjj 12i50in 1lr1m88 uogd4s 1adhs7a 6a0jil 1oibaro 2n7e8w 8dlaw4 fgarak 184mh9w nnqsg7 gutk1c 1sie4w0 12wrn04 1afdtvl 1nx1n9o 3u4ty e34daq 18qmp7x 1dx5sw3 1u6e9kj 1fj0dcx vgqfmk 1picsh9 1lcurq7 1vhlhmi 17g6edo g2sul7 1ko3i1k 1vp010f 1rxhvvo 13c3x0w 1a1r7sb p0k6ju gqlffq 10pylyi 1xoidvm 1ykvrk6 kma813 15j7fnr war30n 10z7emy 1whcq7 1xdnlk5 10mg97d foyide 1lx34my 144i0wq 1kq79li 1rjq8gp 16agjqd 1uk2nuw 19cdu5a 133wuwu 1gquror 12anxc3 1d0cqww 4zp531 8f8xdi 1h0y4i5 syehj7 nyjpex 1hyrt2g 18k6wpx o3ys0u gyqss5 lmzaia h19vjk 1m2gifa dh50jt yyr98k 4mfze4 1jac6c2 cv1jz2 ddqa90 fksa8h n65gq3 1n9j64s 19sk4h4 147xtl9 1r5qcd8 4ut3yi dyjx0f 1fdy0l5 aplobz 18182hy 1ir4e44 14b8va1 1d810fm 997a5u odjpwj 1jyrmsq 1t7f977 1w8jvj tza3mu 13pik1q 1fliqpp 142pe7r r9996t 1um3nx 1jtriov 29kerx 1p9ibgf 1hgawz4 1iog7m3 106vfgv 1wayfxy 4g6ai3 lziufc 1xkgsub w1k3wh ee59jl 1oiyjl1 lsbzdp 9zvmc3 1p80smk xp8w2v 1vhakgw qyp8bo">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}body{line-height:1;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}.hidden-non-responsive-inline,.hidden-non-responsive-inline-block,.hidden-non-responsive-block,.hidden-non-responsive-table-cell{display:none !important;}@media only screen and (max-width:599px){.responsive .responsive-small-display-inline-block{display:inline-block !important;}.responsive .responsive-small-display-block{display:block !important;}.responsive .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:780px){.responsive-biz .responsive-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-small-display-block{display:block !important;}.responsive-biz .responsive-small-display-inline{display:inline !important;}}@media only screen and (max-width:1023px){.responsive .responsive-medium-display-inline-block{display:inline-block !important;}.responsive .responsive-medium-display-block{display:block !important;}.responsive .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1240px){.responsive-biz .responsive-medium-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-medium-display-block{display:block !important;}.responsive-biz .responsive-medium-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive .responsive-desktop-small-display-block{display:block !important;}.responsive .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (max-width:1143px){.responsive-biz .responsive-desktop-small-display-inline-block{display:inline-block !important;}.responsive-biz .responsive-desktop-small-display-block{display:block !important;}.responsive-biz .responsive-desktop-small-display-inline{display:inline !important;}}@media only screen and (min-width:1144 ...
#
#     <script>
#         window.yelp = window.yelp || {};
#         window.yelp.critical_css = window.yelp.critical_css || {};
#         window.yelp.critical_css.css_map = {};
#     </script>
#     <!-- css-middleware: bootstrap placeholder --><script>(function() { window.yelp.critical_css.recordDone=function(c,l){l.onload=null;var i=window.yelp.critical_css.css_map[c];window.yelp.critical_css.css_map[c]=i&&Object.keys(i).length?i:{loaded:!1,linkTag:l}}; })()</script>
# <meta name="critical_css_middleware"><link href="https://s3-media0.fl.yelpcdn.com/assets/public/yelp-frontend-gondola-biz-details-pkg.yji-dc93c4e0e0c3e78eab58.css" rel="stylesheet"><link data-chunk="components-RelatedBusinessesCarousel" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-ad59b36f17920d25a77f.chunk.css">
# <link data-chunk="components-CollectionCardCarousel" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-88ca5af3b99587234325.chunk.css">
# <link data-chunk="components-Reviews" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-182d110c591593ff9ce5.chunk.css">
# <link data-chunk="components-BizQuestionsGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css">
# <link data-chunk="components-MoreBusinessInfo" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css">
# <link data-chunk="BizHoursGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-83eda371beaa69e36837.chunk.css">
# <link data-chunk="MapBoxV2GQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-7c9b8efcabefe5260b28.chunk.css">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-f8c360c7c499d583dd83.chunk.css">
# <link data-chunk="components-BizPageConfigurableAlertsGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-b7ac0249144a2954921c.chunk.css">
# <link data-chunk="ClaimStatusGQL" rel="preload" as="style" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-f278275cd0028fbe6fd6.chunk.css">
# <link data-chunk="ClaimStatusGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-8ae154eddd563209dc2d.chunk.js">
# <link data-chunk="components-UnconfirmedReviewAlert" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-cc046bce61ccc3602ec0.chunk.js">
# <link data-chunk="components-BizPageConfigurableAlertsGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-085a68f0f13b6bba3e94.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-d8498e846c94796eb93924389f4032c65f528717.yji-bbfb5e92345beb710d1f.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-134fc7191607aa8b49c169b2433cb28f280bc74a.yji-85515316098fdb65b645.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-2bc656812ad40b2e9ad3f54c8c28ee534e3e16f6.yji-5f1ee22df8759f4d0583.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-b892eeab6e9c80b0beb801fdee46e10700cdb4b0.yji-05f51eba21bc7072a87e.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-5c56a72b66938be043c7.chunk.js">
# <link data-chunk="OnTheMenuGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-d1f1e87729d2f76ad5d9.chunk.js">
# <link data-chunk="MapBoxV2GQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-58464968ae34e23a3f47.chunk.js">
# <link data-chunk="BizHoursGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-6a4391997459f03388f7.chunk.js">
# <link data-chunk="components-MoreBusinessInfo" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-3869ade6c478cd1486d1.chunk.js">
# <link data-chunk="components-BizQuestionsGQL" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-0c72f59dc44f931ed10d.chunk.js">
# <link data-chunk="components-Reviews" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-b5bedc80750e70323c2e.chunk.js">
# <link data-chunk="components-ReviewFeedWarEditor" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-fa588ed7924f1b2e0c7f.chunk.js">
# <link data-chunk="components-CollectionCardCarousel" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-ed23f4db8a5e78f70b63.chunk.js">
# <link data-chunk="components-RelatedBusinessesCarousel" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-0700b243b0f77a1d4560.chunk.js">
# <link data-chunk="components-SEOLinks" rel="preload" as="script" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-cdecd483a05efc9480ea.chunk.js"><link data-chunk="ClaimStatusGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-f278275cd0028fbe6fd6.chunk.css">
# <link data-chunk="components-BizPageConfigurableAlertsGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-b7ac0249144a2954921c.chunk.css">
# <link data-chunk="OnTheMenuGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-f8c360c7c499d583dd83.chunk.css">
# <link data-chunk="OnTheMenuGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-7c9b8efcabefe5260b28.chunk.css">
# <link data-chunk="MapBoxV2GQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-4881c82d23ae7af43e76.chunk.css">
# <link data-chunk="BizHoursGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-83eda371beaa69e36837.chunk.css">
# <link data-chunk="components-MoreBusinessInfo" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-2b847120a4c94e3ba1f2.chunk.css">
# <link data-chunk="components-BizQuestionsGQL" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-f99580137c641aaab850.chunk.css">
# <link data-chunk="components-Reviews" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-182d110c591593ff9ce5.chunk.css">
# <link data-chunk="components-CollectionCardCarousel" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-88ca5af3b99587234325.chunk.css">
# <link data-chunk="components-RelatedBusinessesCarousel" rel="stylesheet" href="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-ad59b36f17920d25a77f.chunk.css"><link data-rh="true" rel="alternate" media="only screen and (max-width: 640px)" href="https://m.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"><link data-rh="true" rel="search" type="application/opensearchdescription+xml" href="/opensearch" title="Yelp"><link data-rh="true" rel="canonical" href="https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5"><link data-rh="true" rel="alternate" href="android-app://com.yelp.android/yelp-app-indexing/biz/r_BrIgzYcwo1NAuG9dLbpg?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google"><link data-rh="true" rel="alternate" href="ios-app://284910350/yelp//biz/r_BrIgzYcwo1NAuG9dLbpg?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google"><script data-rh="true">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THHF2RF');</script><script data-rh="true" type="application/ld+json">{"@context":"https://schema.org","@type":"Organization","name":"Yelp","url":"http://www.yelp.com","sameAs":["https://www.facebook.com/yelp","https://twitter.com/yelp","https://www.linkedin.com/company/31517","https://instagram.com/yelp"]}</script><script data-rh="true">!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><title data-rh="true">PAI NORTHERN THAI KITCHEN - 4443 Photos &amp; 3244 Reviews - 18 Duncan Street, Toronto, ON - Yelp</title><meta data-rh="true" name="description" content="Delivery &amp; Pickup Options - 3244 reviews of Pai Northern Thai Kitchen &quot;PAI is Chef Nuit's latest venture and we were excited to sample the menu for their soft opening.  The menu has our all time favourites, Squash Fritters, Red Flame Morning Glory, Pad Thai and, of course, Khoa Soi.  The new items include, Moo Ping [Northern Thai sweet grilled pork on skewer], Gaeng Hunglay [pork belly curry with ginger and roasted peanut].
#
# Everything was delicious, like a home cooked meal in Northern Thailand.  Chef Nuit has high standards for her food and this new restaurant is no exception.&quot;"><meta data-rh="true" name="yelp-biz-id" content="r_BrIgzYcwo1NAuG9dLbpg"><meta data-rh="true" name="keywords" content="Yelp,recommendation,San Francisco, bay area, local,business,review,friend,restaurant,dentist,doctor,salon,spa,shopping,store,share,community,massage,sushi,pizza,nails,New York,Los Angeles"><meta data-rh="true" property="og:site_name" content="Yelp"><meta data-rh="true" property="og:type" content="yelpyelp:business"><meta data-rh="true" property="og:image" content="https://s3-media0.fl.yelpcdn.com/bphoto/9QruaHywVEtolW9ELorHpA/o.jpg"><meta data-rh="true" property="og:image:height" content="1754"><meta data-rh="true" property="og:image:width" content="1996"><meta data-rh="true" property="og:title" content="Pai Northern Thai Kitchen - Toronto, ON"><meta data-rh="true" property="og:url" content="https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"><meta data-rh="true" property="og:description" content="Specialties: PAI serves authentic Thai cuisine, specializing in Thai street food and dishes from the northern Thai region. The restaurant, voted Best Thai Restaurant in Toronto several years running, has customers coming back time and again for her garlicky fried tiger prawns and savory Thai chicken wings, aromatic curries, sizzling stir-fries and, of course, her signature Chef Nuit Pad Thai. PAI serves dishes that are inspired by Chef Nuit's life growing up in northern Thailand and also current trends in Thai cuisine. It is recognized by the Thai government for its high-standard and authenticity of food, cooking methods, hospitality, and atmosphere with the prestigious Thai SELECT Signature certification. Established in 2014.  I remember hanging up the sign for our first restaurant, the Curry Shack.  It was in a small town called Pai, in Northern Thailand.   I knew that I loved Chef Nuit's food, but would others love it too?  Born and raised in Thailand, Chef Nuit Regular was cooking for as long as she could remember.  Not only did she help her mom cook for the family, but they also cooked to sell food for a living. It was no surprise to me that when she took on the restaurant world, she would show that same passion. The food was amazing and the restaurant was packed every night.  So to answer my question, others loved it too!
#
# We are now about to come full circle and hang up another sign called Pai.  Chef Nuit is excited to introduce her life experiences in Northern Thailand, through cooking.  What she would cook with her mom to eat and sell; what she would eat at the markets as she rushed to the hospital for work; and what she eventually would cook for her family.
#
# Welcome to Chef Nuit's world."><meta data-rh="true" property="fb:app_id" content="97534753161"><meta data-rh="true" name="apple-itunes-app" content="app-id=284910350, app-argument=yelp:///biz/r_BrIgzYcwo1NAuG9dLbpg?utm_campaign=default&amp;amp;utm_source=www"><meta data-rh="true" property="al:ios:app_name" content="Yelp"><meta data-rh="true" property="al:ios:app_store_id" content="284910350"><meta data-rh="true" property="al:ios:url" content="https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple"><meta data-rh="true" name="application-name" content="Yelp"><meta data-rh="true" name="msapplication-TileImage" content="https://s3-media0.fl.yelpcdn.com/assets/2/www/img/f5e05563b53a/ico/win8-tile.png"><meta data-rh="true" name="msapplication-TileColor" content="\#FFFFFF"><meta data-rh="true" name="msapplication-starturl" content="https://www.yelp.ca"><meta data-rh="true" name="msapplication-navbutton-color" content="\#FF1A1A"><meta data-rh="true" name="msapplication-window" content="width=1024;height=768"><meta data-rh="true" name="msapplication-tooltip" content="Go to https://www.yelp.ca"><meta data-rh="true" name="msapplication-task" content="[object Object]"><meta data-rh="true" name="msapplication-task" content="[object Object]"><meta data-rh="true" name="msapplication-task" content="[object Object]">
#
# <script>document.cookie = "xcj=1|QdoaF6zAwXhhMg-HBLa7Ti3TWgJvNKebGzsZTqoEG-I; Domain=.yelp.ca; expires=Fri, 30 Dec 2022 00:56:09 GMT; Max-Age=7776000; Path=/";</script><link rel="search" type="application/opensearchdescription+xml" href="/opensearch" title="Yelp"></head><body class="" style="margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline; line-height: 1;"><noscript></noscript><yelp-react-root><div data-hypernova-key="yelpfrontend__116186__yelpfrontend__GondolaBizDetails__dynamic" data-hypernova-id="c761ae37-5389-46e7-9357-7dfdb96fe0d6"><div class=" toast-list__09f24__miHvH border-color--default__09f24__NPAKY"></div><span class=""><!-- <a href="/biz/outlook-autumn-market-fundamental-catwalk-flimsy-roost-legibility-individualism-grocer-predestination-9">yelp</a> --></span><div class=" v2__09f24__GsUJ_ border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM" data-lcp-target-id="CONSUMER_HEADER"><div class=" css-fksa8h padding-t1-5__09f24__VNyRg padding-b1-5__09f24__M_AcV border-color--default__09f24__NPAKY background-color--gray-extra-light__09f24__UbDJH"><div class=" a11y-menu-container__09f24__V3Frf border-color--default__09f24__NPAKY"></div></div><header class=" consumer-header-container__09f24__ieW2P border--bottom__09f24___mg5X border-color--default__09f24__NPAKY background-color--white__09f24__ulvSM"><div class=" consumer-header__09f24__GAvyT border-color--default__09f24__NPAKY"><div class=" arrange__09f24__LDfbs vertical-align-middle__09f24__zU9sE border-color--default__09f24__NPAKY"><div class=" logo-arrange-unit__09f24__Rbwi3 arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><div class=" margin-r4__09f24__mJ91T margin-sm-r0__09f24__WfNsG border-color--default__09f24__NPAKY"><div class=" logo__09f24__ip022 logo-image__09f24__SXMH_ logo-container__09f24__jaSQB border-color--default__09f24__NPAKY" style="background-image:url(https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_design_cdn/7ef71bf77a33/assets/img/brand/logo_desktop.svg)" id="logo" data-analytics-label="logo"><a href="/" class="logo-link__09f24__fS20h css-1sie4w0" role="link">Yelp</a></div></div></div><div class=" search-suggest-arrange-unit__09f24__zqa_F arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" search-suggest-container-outer__09f24__SUL4j border-color--default__09f24__NPAKY"><div class=" search-suggest-container-inner__09f24__WsMGR border-color--default__09f24__NPAKY"><div class=" arrange__09f24__LDfbs gutter-2__09f24__CCmUo border-color--default__09f24__NPAKY"><div class=" arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" search-suggest__09f24__Yd8a9"><div class=""><form class=" find-near-form__09f24__qHR1I" action="/search" id="header_find_form" role="search" method="get"><div class=" undefined arrange__09f24__LDfbs border-color--default__09f24__NPAKY"><div class=" arrange-unit__09f24__rqHTg arrange-unit-fill__09f24__CUubG border-color--default__09f24__NPAKY"><div class=" find-near-arrange__09f24__czL3z find-near-arrange--height__09f24__uFYD6 arrange__09f24__LDfbs layout-equal__09f24__odeM0 border-color--default__09f24__NPAKY"><div class=" find-near-arrange-unit__09f24__hvHOu arrange-unit__09f24__rqHTg border-color--default__09f24__NPAKY"><label class=" label__09f24__y83zE pseudo-input__09f24__nfxxT pseudo-input--find-near__09f24__o_Lff pseudo-input--find__09f24__dWbac pseudo-input__09f24__bK86t" for="search_description"><span class=" pseudo-input-text__09f24__PW2ow display--inline__09f24__c6N_k border-color--default__09f24__NPAKY"><div class=" pseudo-input-icon-container__09f24__WCnQN margin-r1-5__09f24__ot4bd border-color--default__09f24__NPAKY"><span aria-label="Find" alt="Find" aria-hidden="false" role="img" class="icon--18-search-small pseudo-input-icon__09f24__b1eFr css-n65gq3"><svg width="18" height="18" class="icon_svg"><path d="M15.913 14.224a1.324 1.3 ...
# <script type="application/json" data-hypernova-key="yelpfrontend__116186__yelpfrontend__GondolaBizDetails__dynamic" data-hypernova-id="c761ae37-5389-46e7-9357-7dfdb96fe0d6"><!--{"locale":"en_CA","messages":{"address, neighborhood, city, state or zip":"address, neighbourhood, city, prov. or postal code","ZIP Code":"Postal Code","We didn't recognize one of your addresses. Please enter at least a city and a state or a ZIP code.":"We didn't recognize one of your addresses. Please enter at least a city and a province or a postal code."},"requestCookies":{},"requestHeaders":{},"requestPath":"/biz/pai-northern-thai-kitchen-toronto-5","requestUrl":"https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants","routeParams":{"businessEncidOrAlias":"pai-northern-thai-kitchen-toronto-5"},"userId":null,"bizUserId":null,"uniqueRequestId":"59f79ef37aefe576","site":"www","gaConfig":{"clientID":"DEDD6D54D8CC577E","dimensions":{"global":{"full_url":[15,"/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"],"internal_ip":[18,false],"referrer":[28,"none"]},"www":{"full_url":[34,"/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"],"internal_ip":[27,false],"referrer":[64,"none"]}},"domain":"yelp.ca","enable_high_volume_events":false,"ga_enabled":true,"js_dimensions":{"global":{},"www":{}},"metrics":{"global":{},"www":{}},"trackers":{"www":"UA-30501-24","global":"UA-30501-1"},"user_id":null},"guv":"DEDD6D54D8CC577E","legacyProps":{"bizDetailsProps":{"bizDetailsMetaProps":{"businessId":"r_BrIgzYcwo1NAuG9dLbpg","staticUrl":"https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants","selectedReviewId":null,"interfaceLanguageCode":"en","cityPageAlias":"toronto","appLinks":{"androidUrl":null,"iosUrl":"https://www.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=apple"},"disallowedRobotsDirectives":null,"googleAppTags":{"androidUrl":"android-app://com.yelp.android/yelp-app-indexing/biz/r_BrIgzYcwo1NAuG9dLbpg?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google","iosUrl":"ios-app://284910350/yelp//biz/r_BrIgzYcwo1NAuG9dLbpg?utm_campaign=biz_details&amp;utm_medium=organic&amp;utm_source=google"},"msiteUrl":"https://m.yelp.ca/biz/pai-northern-thai-kitchen-toronto-5?osq=Restaurants"},"bizDetailsPageProps":{"adUnitsAboveReviewProps":null,"adUnitsBelowReviewProps":null,"adUnitsSidebarProps":null,"autoOpeningMessagingModalProps":{"iframeUrls":{"mtb_search_ad":"/mtb_composer/business/r_BrIgzYcwo1NAuG9dLbpg/entry_point/mtb_search_ad?source_request_id=b700946a1c534acf","mtb_landing_page":"/mtb_composer/business/r_BrIgzYcwo1NAuG9dLbpg/entry_point/mtb_landing_page?source_request_id=b700946a1c534acf","third_party_deep_link":"/mtb_composer/business/r_BrIgzYcwo1NAuG9dLbpg/entry_point/third_party_deep_link?source_request_id=b700946a1c534acf","mtb_search_action":"/mtb_composer/business/r_BrIgzYcwo1NAuG9dLbpg/entry_point/mtb_search_action?source_request_id=b700946a1c534acf"}},"bizDiscoveryTopPitchProps":null,"bizPortfolioProps":null,"bizQuestionsProps":null,"businessAlertProps":null,"businessId":"r_BrIgzYcwo1NAuG9dLbpg","businessIsAdvertiser":false,"businessName":"Pai Northern Thai Kitchen","businessPostsCarouselProps":null,"callToActionProps":null,"conversationWidgetProps":null,"checkInOfferProps":null,"cityPageAlias":"toronto","collectionCardCarouselProps":{"collections":[{"url":"/collection/rK2VbYfOXL3SVXKzObXJ8w","itemCount":9,"name":"Toronto Weekly Roundup","owner":{"displayName":"Yelp I."},"photos":[{"sourceUrl":"https://s3-media0.fl.yelpcdn.com/bphoto/NdPPUsq5L7gAJ-mqr6t7-w/300s.jpg"}]},{"url":"/collection/EcwmLcb5oS5hqdgFSQnyew","itemCount":10,"name":"Toronto’s Elite Picks","owner":{"displayName":"Yelp I."},"photos":[{"sourceUrl":"https://s3-media0.fl.yelpcdn.com/bphoto/BDlB-XFxulUxCGQ9vxGZxw/300s.jpg"}]},{"url":"/collection/pJ96sh_AiotCj2QwsJ8_lA","itemCount":30,"name":"30 Must Try Restaurants in Toronto, Winter 2019","owner":{"displayName": ...
# <script src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/64141792105e/assets/vendor/react-dom/18.2.0/umd/react-dom.production.min.js" integrity="sha384-bm7MnzvK++ykSwVJ2tynSE5TRdN+xL418osEVF2DE/L/gfWHj91J2Sphe582B1Bh" crossorigin="anonymous"></script>
# <!-- css-middleware: body tag placeholder --><script>(function() { var e=window.yelp.critical_css;function t(e){setTimeout(e,0)}function n(n){for(var o in e.css_map)if(!e.css_map[o].loaded)return;t(n)}function o(t,o){var a=e.css_map[t],i=a.linkTag,r=document.querySelector('style[data-critical-css="'+t+'"]');if(r&&i&&!a.loaded){var c=function(e,t){var n=e.cloneNode();n.rel="stylesheet",n.media="all",n.href=e.href;var o=function(){this.onload=null,this.setAttribute("onload",null),t.parentNode.removeChild(t)};return n.setAttribute("onload",o),n.onload=o,n}(i,r);r.insertAdjacentElement("afterend",c),i.parentNode.removeChild(i),e.css_map[t].loaded=!0,n(o)}else n(o)}function a(n,a){if(!e.css_map||0===Object.keys(e.css_map).length)return void t(n);(a?[a]:Object.keys(e.css_map)).forEach((function(t){e.lowPriorityMode?o(t,n):setTimeout(o,0,t,n)}))}e.criticalCSSReady=function(t){const n=(o=t,function(){return o&&(r=o.apply(i||this,arguments),o=null),r});var o,i,r;a(n);var c=e.recordDone.bind(window);e.recordDone=function(e,t){c.call(this,e,t),a(n,t.dataset.criticalCss)}}; })()</script>
# <script>
#         window.yelp = window.yelp || {};
#         window.yelp.zipkin_id = 'f9cc9866e23255fe';
#         window.yelp.unique_request_id = '59f79ef37aefe576';
#         window.yelp.guv = 'DEDD6D54D8CC577E';
#         window.yelp.yuv_record = 'G3XujSzgr0yjmAUHCci2tPXPPoSOIYhBNkHkhDVy-zXVFitnN1aQ6eCFu9zyXR3JgcL0jN369WtBQx1GcgbiDwDxucVPff9T';
#     </script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/srv0/cdn_assets/4dc644e84e0b/assets/vendor/regenerator-runtime/0.13.9/regenerator-runtime.min.js" integrity="sha384-VWXV8VA+0xZuNh5mksoTGTWM4qM9gdLvcv/y/f3Ps2ZjKN37taVfpJHexdLG2bJI" crossorigin="anonymous"></script>
# <script id="yelp-js-error-reporting-init-error-reporting" type="application/json">{"config": {"release": "5f3cc1e87d1759f62de4ef510113e025915e031e", "metaData": {"projectName": "gondola-biz-details", "activeVersion": "1.16.186", "deploymentPreviewId": null, "zipkinTraceID": "f9cc9866e23255fe"}, "environment": "prod", "blacklist": {"location": ["yl[a-z]-[a-z]*\\.js"], "type": [], "message": ["Blocked a frame with origin"]}, "sampleRate": 1}, "client": "bugsnag", "apiKey": "7a505cfcfc5a2e124a4f37054c4d684d", "enabled": true}</script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[4591,5119,5147,7989,2216,8041,6535,5188,2147,8370,8471,1705,6048,5903,45,1755,7854,6751]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["ClaimStatusGQL","components-UnconfirmedReviewAlert","components-BizPageConfigurableAlertsGQL","OnTheMenuGQL","MapBoxV2GQL","BizHoursGQL","components-MoreBusinessInfo","components-BizQuestionsGQL","components-Reviews","components-ReviewFeedWarEditor","components-CollectionCardCarousel","components-RelatedBusinessesCarousel","components-SEOLinks"]}</script>
# <script async data-chunk="ClaimStatusGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/ClaimStatusGQL.yji-8ae154eddd563209dc2d.chunk.js"></script>
# <script async data-chunk="components-UnconfirmedReviewAlert" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-UnconfirmedReviewAlert.yji-cc046bce61ccc3602ec0.chunk.js"></script>
# <script async data-chunk="components-BizPageConfigurableAlertsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizPageConfigurableAlertsGQL.yji-085a68f0f13b6bba3e94.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-d8498e846c94796eb93924389f4032c65f528717.yji-bbfb5e92345beb710d1f.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-134fc7191607aa8b49c169b2433cb28f280bc74a.yji-85515316098fdb65b645.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-2bc656812ad40b2e9ad3f54c8c28ee534e3e16f6.yji-5f1ee22df8759f4d0583.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-b892eeab6e9c80b0beb801fdee46e10700cdb4b0.yji-05f51eba21bc7072a87e.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/shared-css.yji-5c56a72b66938be043c7.chunk.js"></script>
# <script async data-chunk="OnTheMenuGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/OnTheMenuGQL.yji-d1f1e87729d2f76ad5d9.chunk.js"></script>
# <script async data-chunk="MapBoxV2GQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/MapBoxV2GQL.yji-58464968ae34e23a3f47.chunk.js"></script>
# <script async data-chunk="BizHoursGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/BizHoursGQL.yji-6a4391997459f03388f7.chunk.js"></script>
# <script async data-chunk="components-MoreBusinessInfo" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-MoreBusinessInfo.yji-3869ade6c478cd1486d1.chunk.js"></script>
# <script async data-chunk="components-BizQuestionsGQL" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-BizQuestionsGQL.yji-0c72f59dc44f931ed10d.chunk.js"></script>
# <script async data-chunk="components-Reviews" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-Reviews.yji-b5bedc80750e70323c2e.chunk.js"></script>
# <script async data-chunk="components-ReviewFeedWarEditor" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-ReviewFeedWarEditor.yji-fa588ed7924f1b2e0c7f.chunk.js"></script>
# <script async data-chunk="components-CollectionCardCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-CollectionCardCarousel.yji-ed23f4db8a5e78f70b63.chunk.js"></script>
# <script async data-chunk="components-RelatedBusinessesCarousel" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-RelatedBusinessesCarousel.yji-0700b243b0f77a1d4560.chunk.js"></script>
# <script async data-chunk="components-SEOLinks" src="https://s3-media0.fl.yelpcdn.com/assets/public/components-SEOLinks.yji-cdecd483a05efc9480ea.chunk.js"></script>
# <script>window.ySitRepParams = {"guv": "DEDD6D54D8CC577E", "datacenter": "us-east-1", "unique_request_id": "59f79ef37aefe576"};</script>
#
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_runtime.yji-20ac909a973db4b3e6cd.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-moment-2.29.3.yji-7123e11076f2bc23de27.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-luxon-1.26.0.yji-abec18edd0f2d8bd247d.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-lodash-4.17.21.yji-ec5090f63d408b938d4f.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-immutable-4.1.0.yji-f90bcc75a5558eb3ebec.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-style-utils-5.5.1.yji-e191699d1cf627ac775d.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-ynra-18.0.0.yji-e630adeee92e088dae22.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_lib-yelp-react-component-photo-box-13.0.0.yji-aabd06a42e3122204bfd.js" crossorigin="anonymous"></script>
# <script src="https://s3-media0.fl.yelpcdn.com/assets/public/module_yelp-frontend_gondola-biz-details.yji-f159d58315d7276d1d49.js" crossorigin="anonymous"></script><script type="text/javascript">window.yelp.initReactComponents();</script></body></html>

# %%
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id="ResultsContainer")

# %%
# df = pd.read_csv(URL)

# %%
# df.head(10)

# %%
df.shape
# Out:
# (13599, 15)

# %%
# df.info()

# %%
# df.describe()

# %%
# df.isna().sum()
