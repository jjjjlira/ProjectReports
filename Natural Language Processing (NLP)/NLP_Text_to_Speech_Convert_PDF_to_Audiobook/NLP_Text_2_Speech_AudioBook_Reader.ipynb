# %% [markdown]
# # Create an Audiobook from a PDF
# ## Text to Speech conversion and Extraction of Text from PDF files in the creation of an audiobook from a PDF file

# %% [markdown]
# ### Steps
# - Extract text from PDF file
# - Clean the text
# - Convert the text into speech
# - Save the speech
# - Play the speech

# %% [markdown]
# ## 1. Extract text from PDF
# - Use PyPDF2

# %% [markdown]
# ### Install the library

# %%
# ! pip install PyPDF2

# %%
# Installing the library
# !pip install PyMuPDF

# %% [markdown]
# ### Import the library

# %%
import sys, fitz

# %% [markdown]
# ### Extract the text

# %%
fname= "attentionisallyouneed.pdf"
doc =fitz.open(fname)

# %% [markdown]
# ### Print the extracted text

# %%
# Generating the text file 
text =''
for page in doc:
  text =text + str(page.get_text())
text = text.strip()
text
# Out:
# 'Attention Is All You Need \n \nAbstract \nThe dominant sequence transduction models are based on complex recurrent or \nconvolutional neural networks that include an encoder and a decoder. The best \nperforming models also connect the encoder and decoder through an attention \nmechanism. We propose a new simple network architecture, the Transformer, \nbased solely on attention mechanisms, dispensing with recurrence and convolutions \nentirely. Experiments on two machine translation tasks show these models to \nbe superior in quality while being more parallelizable and requiring significantly \nless time to train. Our model achieves 28.4 BLEU on the WMT 2014 Englishto- \nGerman translation task, improving over the existing best results, including \nensembles, by over 2 BLEU. On the WMT 2014 English-to-French translation task, \nour model establishes a new single-model state-of-the-art BLEU score of 41.8 after \ntraining for 3.5 days on eight GPUs, a small fraction of the training cos
# ...

# %% [markdown]
# ## 2. Convert the Text into Speech
# - Use **pyttsx3** OR **gTTS**

# %% [markdown]
# ### Install the library

# %%
# !pip install pyttsx3

# %% [markdown]
# ### Import the library

# %%
import os
from gtts import gTTS

# %% [markdown]
# ### Initialize a Speaker object

# %%
language = 'en'

# %% [markdown]
# ### Convert the text

# %%
speech = gTTS(text = text, 
              lang = language, 
              slow = False)

# %% [markdown]
# ### Save the audio

# %%
speech.save('Jose_Lira_Final_Exam_Q3_speech_1.wav')

# %% [markdown]
# ### Play the speech

# %%
import IPython
IPython.display.display(IPython.display.Audio('speech_0011.wav'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
